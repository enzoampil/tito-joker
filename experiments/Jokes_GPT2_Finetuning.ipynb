# %% [markdown]
# <a href="https://colab.research.google.com/github/enzoampil/tito-joke-generator/blob/master/experiments/Jokes_GPT2_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/huggingface/pytorch-transformers.git
# Out:
# Cloning into 'pytorch-transformers'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 8358 (delta 2), reused 3 (delta 0), pack-reused 8349
# Receiving objects: 100% (8358/8358), 4.51 MiB | 10.57 MiB/s, done.
# Resolving deltas: 100% (6011/6011), done.

# %%
# !pip install pytorch_transformers
# Out:
# ...
#      |████████████████████████████████| 184kB 4.4MB/s
# ...
#      |████████████████████████████████| 1.0MB 42.4MB/s
# ...
#      |████████████████████████████████| 655kB 39.6MB/s
# ...
#      |████████████████████████████████| 860kB 36.2MB/s
# ...
#   Created wheel for regex: filename=regex-2019.8.19-cp36-cp36m-linux_x86_64.whl size=609227 sha256=4593f1b34ca40941cc733d39592842f173bd25be020e2d404cef5ac30c8c96c3
#   Stored in directory: /root/.cache/pip/wheels/90/04/07/b5010fb816721eb3d6dd64ed5cc8111ca23f97fdab8619b5be
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.34-cp36-none-any.whl size=883992 sha256=87b0e5349e0199a568aadf36ef1ddb17d7421ebc60d4d302d5ff8ba5a46ce52a
#   Stored in directory: /root/.cache/pip/wheels/07/b9/5b/8bd674c23e962fbff34420a9fa7a2c374d591ecadd5bc37684
# Successfully built regex sacremoses
# ...

# %%
pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 225kB 4.7MB/s
# ...

# %% [markdown]
# # Let's try with the jokes

# %%
from google import colab

# %%
colab.files.upload()
# Out:
#      <input type="file" id="files-336d0af0-c2e0-4964-b2bc-343535422ead" name="files[]" multiple disabled />
#      <output id="result-336d0af0-c2e0-4964-b2bc-343535422ead">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-504537e09bde> in <module>()
# ----> 1 colab.files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
#      65   files = _collections.defaultdict(_six.binary_type)
# ...

# %%
# !python /content/pytorch-transformers/examples/run_lm_finetuning.py\
    --output_dir=output\
    --model_type=gpt2\
    --model_name_or_path=gpt2\
    --do_train\
    --train_data_file=/content/riddle_jokes.txt \
    --per_gpu_train_batch_size 2
# Out:
# 09/23/2019 01:45:34 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 09/23/2019 01:45:34 - INFO - pytorch_transformers.modeling_utils -   loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/gpt2-config.json from cache at /root/.cache/torch/pytorch_transformers/4be02c5697d91738003fb1685c9872f284166aa32e061576bbe6aaeb95649fcf.085d5f6a8e7812ea05ff0e6ed0645ab2e75d80387ad55c1ad9806ee70d272f80
# 09/23/2019 01:45:34 - INFO - pytorch_transformers.modeling_utils -   Model config {
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
#   "summary_activation": null,
# ...

# %%
colab.files.download('/content/output/config.json')
colab.files.download('/content/output/tokenizer_config.json')
colab.files.download('/content/output/special_tokens_map.json')
colab.files.download('/content/output/vocab.json')
colab.files.download('/content/output/merges.txt')
colab.files.download('/content/output/added_tokens.json')
colab.files.download('/content/output/pytorch_model.bin')

# %%
colab.files.download('/content/output/checkpoint-1200/training_args.bin')

# %%
cd /
# Out:
# /

# %%
# !git clone https://github.com/enzoampil/pytorch-transformers.git
# Out:
# Cloning into 'pytorch-transformers'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 8362 (delta 2), reused 4 (delta 0), pack-reused 8349
# Receiving objects: 100% (8362/8362), 4.52 MiB | 746.00 KiB/s, done.
# Resolving deltas: 100% (6011/6011), done.

# %% [markdown]
# # Inference w/ Riddle Jokes

# %%
# !python /pytorch-transformers/examples/run_generation.py \
    --model_type=gpt2 \
    --model_name_or_path=/content/output/ \
    --length=100 \
    --stop_token=eoj
# Out:
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   Model name '/content/output/' not found in model shortcut name list (gpt2, gpt2-medium, gpt2-large). Assuming '/content/output/' is a path or url to a directory containing tokenizer files.
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   loading file /content/output/vocab.json
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   loading file /content/output/merges.txt
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   loading file /content/output/added_tokens.json
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   loading file /content/output/special_tokens_map.json
# 09/22/2019 13:46:57 - INFO - pytorch_transformers.tokenization_utils -   loading file /content/output/tokenizer_config.json
# 09/22/2019 13:46:58 - INFO - pytorch_transformers.modeling_utils -   loading configuration file /content/output/config.json
# ...

# %%
from pytorch_transformers import GPT2LMHeadModel, GPT2Tokenizer
from pytorch_transformers import OpenAIGPTLMHeadModel, OpenAIGPTTokenizer
from pytorch_transformers import XLNetLMHeadModel, XLNetTokenizer
from pytorch_transformers import TransfoXLLMHeadModel, TransfoXLTokenizer

# %%
MODEL_CLASSES = {
    'gpt2': (GPT2LMHeadModel, GPT2Tokenizer),
    'openai-gpt': (OpenAIGPTLMHeadModel, OpenAIGPTTokenizer),
    'xlnet': (XLNetLMHeadModel, XLNetTokenizer),
    'transfo-xl': (TransfoXLLMHeadModel, TransfoXLTokenizer),
}

# %%
model_class, tokenizer_class = MODEL_CLASSES['gpt2']

# %%
tokenizer = tokenizer_class.from_pretrained('/content/output/checkpoint-1200/')
# Out:
# Model name '/content/output/checkpoint-1200/' was not found in model name list (gpt2, gpt2-medium, gpt2-large). We assumed '/content/output/checkpoint-1200/' was a path or url but couldn't find tokenizer filesat this path or url.
